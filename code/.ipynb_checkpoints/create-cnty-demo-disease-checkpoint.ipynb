# %%
import pandas as pd
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
def create_real_fips(ffips):
    if (len(ffips) == 1) or (len(ffips) == 4):
        return '0'+ffips
    else:
        return ffips

# %% [markdown]
# ## CENSUS AGE COUNTS

# %%
trows = ['GEO_ID','NAME','DP05_0001E','DP05_0005E','DP05_0006E','DP05_0007E',
         'DP05_0008E','DP05_0009E','DP05_0010E','DP05_0011E','DP05_0012E',
         'DP05_0013E','DP05_0014E','DP05_0015E','DP05_0016E','DP05_0017E',
         'DP05_0018E','DP05_0023E','DP05_0024E']

age = pd.read_csv('../data/ACSDP5Y2018.DP05_2020-03-17T094943/ACSDP5Y2018.DP05_data_with_overlays_2020-03-17T093715.csv',
                        usecols=trows)

col_rename = {'DP05_0001E':'pop','DP05_0005E':'pop_under5','DP05_0006E':'pop_5to9','DP05_0007E':'pop_10to14',
             'DP05_0008E':'pop_15to19','DP05_0009E':'pop_20to24','DP05_0010E':'pop_25to34',
              'DP05_0011E':'pop_35to44','DP05_0012E':'pop_45to54','DP05_0013E':'pop_55to59',
              'DP05_0014E':'pop_60to64','DP05_0015E':'pop_65to74','DP05_0016E':'pop_75to84',
              'DP05_0017E':'pop_85plus','DP05_0018E':'median_age','DP05_0023E':'pop_62plus',
              'DP05_0024E':'pop_65plus'}
age = age.rename(columns=col_rename)

#remove the line that contains the hr column titles
age = age.loc[~(age.index == 0)]
age['cnty_fips'] = age['GEO_ID'].str[-5:]
age['pop_62plus'] = pd.to_numeric(age['pop_62plus'],errors='coerce')
age['pop_65plus'] = pd.to_numeric(age['pop_65plus'],errors='coerce')
age['pop_85plus'] = pd.to_numeric(age['pop_85plus'],errors='coerce')

age.set_index('cnty_fips', inplace=True)
# Out:
# /Users/akanik/.virtualenvs/covid19/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (235,251,255,259,263,267,271,275,279,283,287,291,295,299,303,323,327) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
age.head()
# Out:
#                    GEO_ID                     NAME     pop pop_under5 pop_5to9 pop_10to14 pop_15to19 pop_20to24 pop_25to34 pop_35to44 pop_45to54 pop_55to59 pop_60to64 pop_65to74 pop_75to84 pop_85plus median_age  pop_62plus  pop_65plus
# cnty_fips
# 01001      0500000US01001  Autauga County, Alabama   55200       3263     4009       3570       3855       3337       7064       7374       7853       4131       2694       4711       2524        815       37.8        9403        8050
# 01003      0500000US01003  Baldwin County, Alabama  208107      11609    11689      14323      12707      10790      23326      25377      28330      14440      14851      24551      12165       3949       42.8       49811       40665
# 01005      0500000US01005  Barbour County, Alabama   25782       1390     1450       1677       1434       1658       3675       3104       3452       1657       1651       2820       1392        422       39.9        5658        4634
# ...

# %% [markdown]
# ## CENSUS AGE PERCENTAGES

# %%
prows = ['GEO_ID','NAME','DP05_0001E','DP05_0005PE','DP05_0006PE','DP05_0007PE',
         'DP05_0008PE','DP05_0009PE','DP05_0010PE','DP05_0011PE','DP05_0012PE',
         'DP05_0013PE','DP05_0014PE','DP05_0015PE','DP05_0016PE','DP05_0017PE',
         'DP05_0018E','DP05_0023PE','DP05_0024PE']

perc_age = pd.read_csv('../data/ACSDP5Y2018.DP05_2020-03-17T094943/ACSDP5Y2018.DP05_data_with_overlays_2020-03-17T093715.csv',
                        usecols=prows)

col_rename = {'DP05_0001E':'pop','DP05_0005PE':'perc_under5','DP05_0006PE':'perc_5to9','DP05_0007PE':'perc_10to14',
              'DP05_0008PE':'perc_15to19','DP05_0009PE':'perc_20to24','DP05_0010PE':'perc_25to34',
              'DP05_0011PE':'perc_35to44','DP05_0012PE':'perc_45to54','DP05_0013PE':'perc_55to59',
              'DP05_0014PE':'perc_60to64','DP05_0015PE':'perc_65to74','DP05_0016PE':'perc_75to84',
              'DP05_0017PE':'perc_85plus','DP05_0018E':'median_age','DP05_0023PE':'perc_62plus',
              'DP05_0024PE':'perc_65plus'}
perc_age = perc_age.rename(columns=col_rename)

#remove the line that contains the hr column titles
perc_age = perc_age.loc[~(perc_age.index == 0)]
perc_age['cnty_fips'] = perc_age['GEO_ID'].str[-5:]
perc_age['perc_62plus'] = pd.to_numeric(perc_age['perc_62plus'],errors='coerce')
perc_age['perc_65plus'] = pd.to_numeric(perc_age['perc_65plus'],errors='coerce')
perc_age['perc_85plus'] = pd.to_numeric(perc_age['perc_85plus'],errors='coerce')

perc_age.set_index('cnty_fips', inplace=True)
# Out:
# /Users/akanik/.virtualenvs/covid19/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (235,253,257,261,265,269,273,277,281,285,289,293,297,301,303,325,329) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
perc_age.head()
# Out:
#                    GEO_ID                     NAME     pop perc_under5 perc_5to9 perc_10to14 perc_15to19 perc_20to24 perc_25to34 perc_35to44 perc_45to54 perc_55to59 perc_60to64 perc_65to74 perc_75to84 perc_85plus median_age  perc_62plus  perc_65plus
# cnty_fips
# 01001      0500000US01001  Autauga County, Alabama   55200         5.9       7.3         6.5         7.0         6.0        12.8        13.4        14.2         7.5         4.9         8.5         4.6         1.5       37.8         17.0         14.6
# 01003      0500000US01003  Baldwin County, Alabama  208107         5.6       5.6         6.9         6.1         5.2        11.2        12.2        13.6         6.9         7.1        11.8         5.8         1.9       42.8         23.9         19.5
# ...

# %% [markdown]
# ## HOSPITAL DATA
#
# Did not end up using this... but we might still for open/closed hospital designation: https://hifld-geoplatform.opendata.arcgis.com/datasets/hospitals
#
# Ok, here's the skinny on hospitals... so far. The CMS data are probably the best available data on what we want to be tracking re: beds and then also ratings. However, the CMS data have some issues.
#
# 1. VA hospitals are not included because they do not produce CMS cost sheets.
# 2. Larger hospital systems that have multiple hospitals w/i the system may only be represented in the CMS dataset once. This means that mapping of hospitals is not going to accurate.
# 3. The CMS data do not include closed hospitals like the HIFLD data do. So we can't get at hospital closure voids the way we'd want to.
#
# For these reasons, I've decided to merge the CMS and the HIFLD data, to the best of my abilities. The HIFLD data don't have provider IDs attached so I'm going to have to match on names. This is not ideal but we'll clean up where we need to.

# %% [markdown]
# ### CMS hospital data

# %%
import geopandas as gpd

# %%
def csv_to_shp(df):
    gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.lng, df.lat))
    gdf.crs = 'EPSG:4269'
    return gdf

# %%
us_cnty = gpd.read_file('../gis/tl_2019_us_county/tl_2019_us_county.shp')

cms_hosp_beds = pd.read_csv('../data/hospitals/cms_hospital_data-v2.csv')
cms_hosp_dets = pd.read_csv('../data/hospitals/hospital_gen_info_geocoded_final.csv')

# %%
cms_beds_geo = csv_to_shp(cms_hosp_beds)
cms_beds_geo = gpd.sjoin(cms_beds_geo, us_cnty, how="inner", op='intersects')

refine_cols = ['id', 'address', 'city', 'location', 'county_name',
               'emergency_services', 'geocode_accuracy', 'geocode_flag',
               'hospital_name', 'hospital_ownership', 'hospital_type', 'lat', 'lng',
               'phone_number', 'state', 'COUNTYFP', 'COUNTYNS', 'url', 
               'zip_code', 'provider_id_int','provider_id_raw', 'RPT_REC_NUM', 
               'icu_beds', 'burn_beds','surg_icu_beds', 'coronary_beds', 'acute_beds', 
               'total_med_beds','subprovider_ipf_beds', 'subprovider_irf_beds', 
               'subprovider_oth_beds','skilled_nursing_beds', 'nursing_fac_beds', 
               'oth_longterm_beds','hospice_beds', 'all_beds', 'geometry', 
               'index_right', 'STATEFP', 'GEOID', 'NAME', 'NAMELSAD']
cms_hosp_geo = hosp_geo[refine_cols]
cms_hosp_geo['cnty_fips'] = cms_hosp_geo['GEOID'].str[-5:]

cms_hosp_geo['full_addy'] = cms_hosp_geo['address'] + ' ' + cms_hosp_geo['city'] + ' ' + cms_hosp_geo['state']
cms_hosp_geo['full_addy'] = cms_hosp_geo['full_addy'].str.replace('[^\w\s]',' ')
cms_hosp_geo['full_addy'] = cms_hosp_geo['full_addy'].str.replace('ROAD','RD')
cms_hosp_geo['full_addy'] = cms_hosp_geo['full_addy'].str.replace('DRIVE','DR')
cms_hosp_geo['full_addy'] = cms_hosp_geo['full_addy'].str.replace('AVENUE','AVE')
cms_hosp_geo['full_addy'] = cms_hosp_geo['full_addy'].str.replace('BOULEVARD','BLVD')
cms_hosp_geo['full_addy'] = cms_hosp_geo['full_addy'].str.replace('STREET','ST')
cms_hosp_geo['full_addy'] = cms_hosp_geo['full_addy'].str.replace('HIGHWAY','HWY')
cms_hosp_geo['full_addy'] = cms_hosp_geo['full_addy'].str.replace('SAINT','ST')
cms_hosp_geo['full_addy'] = cms_hosp_geo['full_addy'].str.replace('MOUNT','MT')
cms_hosp_geo['full_addy'] = cms_hosp_geo['full_addy'].str.replace(' N ',' NORTH ')
cms_hosp_geo['full_addy'] = cms_hosp_geo['full_addy'].str.replace(' S ',' SOUTH ')
cms_hosp_geo['full_addy'] = cms_hosp_geo['full_addy'].str.replace(' E ',' EAST ')
cms_hosp_geo['full_addy'] = cms_hosp_geo['full_addy'].str.replace(' W ',' WEST ')
cms_hosp_geo['full_addy'] = cms_hosp_geo['full_addy'].str.replace(' KY ',' KENTUCKY ')
cms_hosp_geo['full_addy'] = cms_hosp_geo['full_addy'].str.replace(' OH ',' OHIO ')
cms_hosp_geo['full_addy'] = cms_hosp_geo['full_addy'].str.replace(' WV ',' WEST VIRGINIA ')
cms_hosp_geo['full_addy'] = cms_hosp_geo['full_addy'].str.replace('  ',' ')

cms_hosp_geo['name_fips'] = cms_hosp_geo['hospital_name'].str.strip() + ' - ' + cms_hosp_geo['cnty_fips'].str.strip()
# Out:
# /Users/akanik/.virtualenvs/covid19/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
cms_hosp_geo.to_csv('../data/hospitals/cms_hospital_data-v2-SCLEANED.csv',index=False)

# %% [markdown]
# ### HIFLD hospital data

# %%
hifld_hosp = pd.read_csv('../data/hospitals/hifld-hospitals.csv')

hifld_hosp['full_addy'] = hifld_hosp['ADDRESS'] + ' ' + hifld_hosp['CITY'] + ' ' + hifld_hosp['STATE']
hifld_hosp['full_addy'] = hifld_hosp['full_addy'].str.replace('[^\w\s]',' ')
hifld_hosp['full_addy'] = hifld_hosp['full_addy'].str.replace('ROAD','RD')
hifld_hosp['full_addy'] = hifld_hosp['full_addy'].str.replace('DRIVE','DR')
hifld_hosp['full_addy'] = hifld_hosp['full_addy'].str.replace('AVENUE','AVE')
hifld_hosp['full_addy'] = hifld_hosp['full_addy'].str.replace('BOULEVARD','BLVD')
hifld_hosp['full_addy'] = hifld_hosp['full_addy'].str.replace('STREET','ST')
hifld_hosp['full_addy'] = hifld_hosp['full_addy'].str.replace('HIGHWAY','HWY')
hifld_hosp['full_addy'] = hifld_hosp['full_addy'].str.replace('SAINT','ST')
hifld_hosp['full_addy'] = hifld_hosp['full_addy'].str.replace('MOUNT','MT')
hifld_hosp['full_addy'] = hifld_hosp['full_addy'].str.replace(' N ',' NORTH ')
hifld_hosp['full_addy'] = hifld_hosp['full_addy'].str.replace(' S ',' SOUTH ')
hifld_hosp['full_addy'] = hifld_hosp['full_addy'].str.replace(' E ',' EAST ')
hifld_hosp['full_addy'] = hifld_hosp['full_addy'].str.replace(' W ',' WEST ')
hifld_hosp['full_addy'] = hifld_hosp['full_addy'].str.replace(' KY ',' KENTUCKY ')
hifld_hosp['full_addy'] = hifld_hosp['full_addy'].str.replace(' OH ',' OHIO ')
hifld_hosp['full_addy'] = hifld_hosp['full_addy'].str.replace(' WV ',' WEST VIRGINIA ')
hifld_hosp['full_addy'] = hifld_hosp['full_addy'].str.replace('  ',' ')

hifld_hosp['name_fips'] = hifld_hosp['NAME'].str.strip() + ' - ' + hifld_hosp['COUNTYFIPS'].str.strip()

ovr_hifld = hifld_hosp.loc[hifld_hosp['STATE'].isin(['KY','OH','WV'])]

# %%
hifld_hosp.to_csv('../data/hospitals/hifld-hospitals-SCLEANED.csv',index=False)

# %% [markdown]
# ### Joini

# %%
hosp_join = cms_hosp_geo.merge(hifld_hosp,how='outer',on='full_addy',suffixes=('_cms','_hifld'))

min_cols = ['id','provider_id_raw', 'address', 'city', 'COUNTYFP', 'county_name',
            'hospital_type','total_med_beds','hospital_name','state','full_addy',
            'NAME_hifld', 'STATE','TYPE', 'STATUS','cnty_fips','ADDRESS', 'CITY','BEDS']

hosp_min = hosp_join[min_cols]

ovr_states = ['KY','OH','WV']
ovr_hops_join = hosp_min.loc[(hosp_min['state'].isin(ovr_states)) | (hosp_min['STATE'].isin(ovr_states))]

# %%
#hospitals from hifld didn't resolve with CMS
print(len(ovr_hops_join.loc[ovr_hops_join['NAME_hifld'].isna()]))

#hospitals from CMS didn't resolve with HIFLD
print(len(ovr_hops_join.loc[ovr_hops_join['hospital_name'].isna()]))
# Out:
# 29
# 207

# %% [markdown]
# I'm currently going through all of the records that did not resolve and figuring out additional cleaning rules. I'll keep a list of things that need to be done manually.
#
# - PO BOX in address line
# - Weird spacing in city name (eg MCDOWELL vs MC DOWELL, SOIN MEDICAL, BAPTIST HEALTH LA GRANGE)
# - Words instead of numbers in address (might be able to fix this with scripting)
# - Completely different address (OWENSBORO HEALTH REGIONAL HOSPITAL, AKRON CHILDREN'S HOSPITAL)
# - Different city but probably same area (AVITA ONTARIO)
# - Missing street number (WEST VIRGINIA UNIVERSITY HOSPITALS, BROADDUS) -- looks like hospitals located at "1 WHATEVER STREET" sometimes have that numeral stripped in the HIFLD data
# - Additional/missing directionality in address (PLATEAU MEDICAL CENTER)
# - County in street address (MONTGOMERY GENERAL)
# - Not actually found in one or the other dataset (88th Medical Group (Wright-Patterson AFB))

# %%
ovr_hops_join.loc[ovr_hops_join['NAME_hifld'].isna()][25:31]
# Out:
#            id provider_id_raw                address         city COUNTYFP county_name              hospital_type  total_med_beds                     hospital_name state                          full_addy NAME_hifld STATE TYPE STATUS cnty_fips ADDRESS CITY  BEDS
# 4531  19740.0          180001  85 NORTH GRAND AVENUE  FORT THOMAS      037    CAMPBELL       Acute Care Hospitals           134.0            ST ELIZABETH FT THOMAS    KY  85 NORTH GRAND AVE FORT THOMAS KY        NaN   NaN  NaN    NaN     21037     NaN  NaN   NaN
# 4670  19579.0          510002  1320 MAPLEWOOD AVENUE   RONCEVERTE      025  GREENBRIER       Acute Care Hospitals            86.0  GREENBRIER VALLEY MEDICAL CENTER    WV   1320 MAPLEWOOD AVE RONCEVERTE WV        NaN   NaN  NaN    NaN     54025     NaN  NaN   NaN
# ...

# %%
ovr_hifld.loc[ovr_hifld['NAME'].str.contains('BAPTIST HEALTH LA GRANGE')]
# Out:
#              X         Y  OBJECTID      ID                      NAME              ADDRESS      CITY STATE    ZIP           ZIP4       TELEPHONE                TYPE STATUS  POPULATION  COUNTY COUNTYFIPS COUNTRY  LATITUDE  LONGITUDE  NAICS_CODE                              NAICS_DESC                                             SOURCE                SOURCEDATE VAL_METHOD                  VAL_DATE                                            WEBSITE STATE_ID                    ALT_NAME  ST_FIPS       OWNER  TTL_STAFF  BEDS         TRAUMA HELIPAD                        full_addy
# ...

# %% [markdown]
# ### By county analysis

# %%
beds_by_cnty = beds_cnty.groupby(['cnty_fips','NAME']).agg({'provider_id_raw':'count',
                                                               'total_med_beds':'sum'})
beds_by_cnty = beds_by_cnty.reset_index().rename(columns={'provider_id_raw':'hospitals'})
beds_by_cnty.set_index('cnty_fips', inplace=True)

# %%
beds_by_cnty.head()
# Out:
#               NAME  hospitals  total_med_beds
# cnty_fips
# 01001      Autauga          1            50.0
# 01003      Baldwin          3           296.0
# 01005      Barbour          1            30.0
# 01007         Bibb          1            25.0
# 01009       Blount          1            25.0

# %% [markdown]
# ## DISEASE DATA: Diabetes
#
# Rates are percentages of the population. Rate out of 100 people.

# %%
diabetes_cols = ['Location','FIPS','Prevalence, 2012, Both Sexes']
diabetes = pd.read_excel('../data/diabetes/IHME_USA_COUNTY_DIABETES_PREVALENCE_1999_2012_NATIONAL_Y2016M08D23.XLSX',
                             sheet_name='Total', skiprows=[0], dtype={'FIPS':str,'Prevalence, 2012, Both Sexes':float})
diabetes = diabetes[diabetes_cols]

# %%
diabetes = diabetes.dropna(subset=['FIPS'])
diabetes['cnty_fips'] = diabetes['FIPS'].apply(lambda x: create_real_fips(x))
diabetes['state_fips'] = diabetes['cnty_fips'].str[:2]

diabetes_2012 = diabetes[['Location','cnty_fips','state_fips','Prevalence, 2012, Both Sexes']]
diabetes_2012.rename(columns={'Prevalence, 2012, Both Sexes':'diabetes_rate'}, inplace=True)

diabetes_2012.set_index('cnty_fips', inplace=True)
# Out:
# /Users/akanik/.virtualenvs/covid19/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
print(len(diabetes_2012))
diabetes_2012.head()
# Out:
# 3193
#                  Location state_fips  diabetes_rate
# cnty_fips
# 01                Alabama         01          16.19
# 01001      Autauga County         01          15.45
# 01003      Baldwin County         01          13.44
# 01005      Barbour County         01          19.36
# 01007         Bibb County         01          16.68

# %% [markdown]
# ## DISEASE DATA: Cardiovascular Disease
#
# Rates are deaths per 100,000 population.

# %%
cvd_data = pd.read_excel('../data/cvd-mortality/IHME_USA_COUNTY_CVD_MORTALITY_RATES_1980_2014_NATIONAL_Y2017M05D16.XLSX',
                       sheet_name='Cardiovascular diseases',skiprows=[0],dtype={'FIPS':str})

# %%
cvd_2014 = cvd_data[['Location', 'FIPS', 'Mortality Rate, 2014*','% Change in Mortality Rate, 1980-2014']]
cvd_2014 = cvd_2014.rename(columns={'Mortality Rate, 2014*':'cvd_rate',
                                    '% Change in Mortality Rate, 1980-2014':'cvd_chg_1980_2014'})
cvd = cvd_2014['cvd_rate'].str.split(pat = "(",expand=True)
cvd_2014['cvd_rate'] = cvd[0].astype('float64')

chg = cvd_2014['cvd_chg_1980_2014'].str.split(pat = "(",expand=True)
cvd_2014['cvd_chg_1980_2014'] = chg[0].astype('float64')

cvd_2014 = cvd_2014.dropna(subset=['FIPS'])
cvd_2014['cnty_fips'] = cvd_2014['FIPS'].apply(lambda x: create_real_fips(x))
cvd_2014['state_fips'] = cvd_2014['cnty_fips'].str[:2]

cvd_2014 = cvd_2014[['Location', 'cnty_fips', 'state_fips', 'cvd_rate', 'cvd_chg_1980_2014']]
cvd_2014.set_index('cnty_fips', inplace=True)

# %%
print(len(cvd_2014))
cvd_2014.head()
# Out:
# 3193
#                           Location state_fips  cvd_rate  cvd_chg_1980_2014
# cnty_fips
# 01                         Alabama         01    310.59             -39.91
# 01001      Autauga County, Alabama         01    316.36             -42.76
# 01003      Baldwin County, Alabama         01    272.04             -38.96
# 01005      Barbour County, Alabama         01    255.09             -50.52
# 01007         Bibb County, Alabama         01    378.09             -31.09

# %% [markdown]
# ## DISEASE DATA: Chronic Respiratory Disease
#
# Rates are deaths per 100,000 population.

# %%
crd_data = pd.read_excel('../data/crd-mortality/IHME_USA_COUNTY_RESP_DISEASE_MORTALITY_1980_2014_NATIONAL_Y2017M09D26.xlsx',
                       sheet_name='Chronic respiratory diseases',skiprows=[0],dtype={'FIPS':str})

# %%
crd_2014 = crd_data[['Location', 'FIPS', 'Mortality Rate, 2014*','% Change in Mortality Rate, 1980-2014']]
crd_2014 = crd_2014.rename(columns={'Mortality Rate, 2014*':'crd_rate',
                                    '% Change in Mortality Rate, 1980-2014':'crd_chg_1980_2014'})

crd = crd_2014['crd_rate'].str.split(pat = "(",expand=True)
crd_2014['crd_rate'] = crd[0].astype('float64')

chg = crd_2014['crd_chg_1980_2014'].str.split(pat = "(",expand=True)
crd_2014['crd_chg_1980_2014'] = chg[0].astype('float64')

crd_2014 = crd_2014.dropna(subset=['FIPS'])
crd_2014['cnty_fips'] = crd_2014['FIPS'].apply(lambda x: create_real_fips(x))
crd_2014['state_fips'] = crd_2014['cnty_fips'].str[:2]

crd_2014 = crd_2014[['Location', 'cnty_fips', 'state_fips', 'crd_rate', 'crd_chg_1980_2014']]
crd_2014.set_index('cnty_fips', inplace=True)

# %%
print(len(crd_2014))
crd_2014.head()
# Out:
# 3193
#                           Location state_fips  crd_rate  crd_chg_1980_2014
# cnty_fips
# 01                         Alabama         01     73.44              73.08
# 01001      Autauga County, Alabama         01     81.79              75.67
# 01003      Baldwin County, Alabama         01     54.28              46.10
# 01005      Barbour County, Alabama         01     69.82              62.98
# 01007         Bibb County, Alabama         01     84.49              83.11

# %% [markdown]
# ## RISK ANALYSIS
#
# We're going to combine covid-19 risk measure by county to create a county-by-county risk analysis.
#
# Datasets defined in this notebook:
# - `crd_2014` - Chronic respiratory disease mortality rates, deaths per 100,000, 2014
# - `cvd_2014` - Cardiovascular disease mortality rates, deaths per 100,000, 2014
# - `diabetes_2012` - Diabetes prevelance, percent of population who has diabetes, 2012
# - `age` - Population by age of population, count of people in age groups, 2018 ACS 5-year
# - `perc_age` - Population by age of population, percent age groups, 2018 ACS 5-year
# - `beds_by_cnty` - CMS hospital count and bed data, 2017 CMS cost reports

# %%
pop_merge = perc_age.join(age,how='left',lsuffix='_perc', rsuffix='_cnt')
cd_merge = cvd_2014.join(crd_2014,how='left',lsuffix='_cvd', rsuffix='_crd')
disease_merge = cd_merge.join(diabetes_2012,how='left',lsuffix='_cd', rsuffix='_dia')
popdisease_merge = pop_merge.join(disease_merge,how='left',lsuffix='_pop', rsuffix='_dis')
risk_data = popdisease_merge.join(beds_by_cnty,how='left',lsuffix='_popdis', rsuffix='_beds')

# %%
keep_cols = ['GEO_ID_perc','state_fips_cvd', 'NAME_perc', 'pop_perc', 'median_age_perc',
             'perc_62plus', 'perc_65plus', 'perc_85plus',
             'pop_62plus', 'pop_65plus', 'pop_85plus',
             'cvd_rate', 'cvd_chg_1980_2014','crd_rate', 'crd_chg_1980_2014','diabetes_rate',
             'hospitals', 'total_med_beds',
             #the columns below can be omitted if you want a shorter dataset
             'perc_under5', 'perc_5to9','perc_10to14', 'perc_15to19', 'perc_20to24', 
             'perc_25to34','perc_35to44', 'perc_45to54', 'perc_55to59', 'perc_60to64',
             'perc_65to74', 'perc_75to84',
             'pop_under5', 'pop_5to9', 'pop_10to14', 'pop_15to19', 'pop_20to24',
             'pop_25to34', 'pop_35to44', 'pop_45to54', 'pop_55to59', 'pop_60to64',
             'pop_65to74', 'pop_75to84']

risk_data = risk_data[keep_cols]
risk_data.rename(columns={'GEO_ID_perc':'geoid','state_fips_cvd':'state_fips','NAME_perc':'cnty_name',
                          'pop_perc':'population','median_age_perc':'median_age'}, inplace=True)

# %%
#Important to note that these are quartiles calculated from regional data only
#Should probably pull in all US
risk_data['us_diabetes_q'] = pd.qcut(risk_data['diabetes_rate'], 4, [1,2,3,4])
risk_data['us_cvd_q'] = pd.qcut(risk_data['cvd_rate'], 4, [1,2,3,4])
risk_data['us_crd_q'] = pd.qcut(risk_data['crd_rate'], 4, [1,2,3,4])
risk_data['us_62plus_q'] = pd.qcut(risk_data['perc_62plus'], 4, [1,2,3,4])

risk_data['us_diabetes_q'] = (risk_data['us_diabetes_q'].astype('category').cat.codes)+1
risk_data['us_cvd_q'] = (risk_data['us_cvd_q'].astype('category').cat.codes)+1
risk_data['us_crd_q'] = (risk_data['us_crd_q'].astype('category').cat.codes)+1
risk_data['us_62plus_q'] = (risk_data['us_62plus_q'].astype('category').cat.codes)+1

risk_data['us_q_total'] = risk_data['us_diabetes_q'] + risk_data['us_cvd_q'] + risk_data['us_crd_q'] + risk_data['us_62plus_q']

# %%
reorder_cols = ['geoid', 'state_fips','cnty_name','population', 'perc_62plus',
                'hospitals', 'total_med_beds','cvd_rate','crd_rate','diabetes_rate',
                'us_diabetes_q','us_cvd_q', 'us_crd_q', 'us_62plus_q', 'us_q_total',
                'cvd_chg_1980_2014', 'crd_chg_1980_2014',
                'perc_65plus', 'perc_85plus', 'pop_62plus', 'pop_65plus', 'pop_85plus',
                'perc_under5','perc_5to9', 'perc_10to14', 'perc_15to19', 'perc_20to24', 
                'perc_25to34','perc_35to44', 'perc_45to54', 'perc_55to59', 'perc_60to64',
                'perc_65to74', 'perc_75to84', 'pop_under5', 'pop_5to9', 'pop_10to14',
                'pop_15to19', 'pop_20to24', 'pop_25to34', 'pop_35to44', 'pop_45to54',
                'pop_55to59', 'pop_60to64', 'pop_65to74', 'pop_75to84', 'median_age']
risk_data = risk_data[reorder_cols]

# %%
risk_data.sort_values('us_q_total', ascending=False).head(10)
# Out:
#                     geoid state_fips                     cnty_name population  perc_62plus  hospitals  total_med_beds  cvd_rate  crd_rate  diabetes_rate  us_diabetes_q  us_cvd_q  us_crd_q  us_62plus_q  us_q_total  cvd_chg_1980_2014  crd_chg_1980_2014  perc_65plus  perc_85plus  pop_62plus  pop_65plus  pop_85plus perc_under5 perc_5to9 perc_10to14 perc_15to19 perc_20to24 perc_25to34 perc_35to44 perc_45to54 perc_55to59 perc_60to64 perc_65to74 perc_75to84 pop_under5 pop_5to9 pop_10to14 pop_15to19 pop_20to24 pop_25to34 pop_35to44 pop_45to54 pop_55to59 pop_60to64 pop_65to74 pop_75to84 median_age
# cnty_fips
# ...

# %%
ovr_risk = risk_data.loc[risk_data['state_fips'].isin(['21','39','54'])]
ovr_risk_nohosp = ovr_risk.loc[ovr_risk['hospitals'].isna()]

# %%
print(len(ovr_risk_nohosp))
ovr_risk_nohosp.sort_values('us_q_total', ascending=False).head(10)
# Out:
# 67
#                     geoid state_fips                      cnty_name population  perc_62plus  hospitals  total_med_beds  cvd_rate  crd_rate  diabetes_rate  us_diabetes_q  us_cvd_q  us_crd_q  us_62plus_q  us_q_total  cvd_chg_1980_2014  crd_chg_1980_2014  perc_65plus  perc_85plus  pop_62plus  pop_65plus  pop_85plus perc_under5 perc_5to9 perc_10to14 perc_15to19 perc_20to24 perc_25to34 perc_35to44 perc_45to54 perc_55to59 perc_60to64 perc_65to74 perc_75to84 pop_under5 pop_5to9 pop_10to14 pop_15to19 pop_20to24 pop_25to34 pop_35to44 pop_45to54 pop_55to59 pop_60to64 pop_65to74 pop_75to84 median_age
# cnty_fips
# ...

# %%
hifld_bycnty = ovr_hifld.groupby(['COUNTYFIPS','COUNTY','STATUS']).agg({'ID':'count','BEDS':'sum'}).reset_index()
hifld_bycnty_ids = list(hifld_bycnty.COUNTYFIPS.unique())

found = ovr_risk_nohosp.loc[ovr_risk_nohosp.index.isin(hifld_bycnty_ids)]
found
# Out:
#                     geoid state_fips                     cnty_name population  perc_62plus  hospitals  total_med_beds  cvd_rate  crd_rate  diabetes_rate  us_diabetes_q  us_cvd_q  us_crd_q  us_62plus_q  us_q_total  cvd_chg_1980_2014  crd_chg_1980_2014  perc_65plus  perc_85plus  pop_62plus  pop_65plus  pop_85plus perc_under5 perc_5to9 perc_10to14 perc_15to19 perc_20to24 perc_25to34 perc_35to44 perc_45to54 perc_55to59 perc_60to64 perc_65to74 perc_75to84 pop_under5 pop_5to9 pop_10to14 pop_15to19 pop_20to24 pop_25to34 pop_35to44 pop_45to54 pop_55to59 pop_60to64 pop_65to74 pop_75to84 median_age
# cnty_fips
# ...

# %%
print(len(ovr_hifld.loc[ovr_hifld['TYPE'] == 'MILITARY']))
ovr_hifld.loc[ovr_hifld['TYPE'] == 'MILITARY']
# Out:
# 16
#               X          Y  OBJECTID         ID                                               NAME                       ADDRESS                  CITY STATE    ZIP           ZIP4       TELEPHONE      TYPE STATUS  POPULATION      COUNTY COUNTYFIPS COUNTRY   LATITUDE  LONGITUDE  NAICS_CODE                              NAICS_DESC                                             SOURCE                SOURCEDATE     VAL_METHOD                  VAL_DATE                                            WEBSITE       STATE_ID       ALT_NAME  ST_FIPS                 OWNER  TTL_STAFF  BEDS         TRAUMA HELIPAD
# ...

# %%
cms_beds2 = pd.read_csv('../data/hospitals/cms_hospital_beds_2017-v3.csv')

# %%
cms_beds2.loc[cms_beds2['facility'].str.contains('SUTTER')]
# Out:
#      provider_id  rpt_rec_num                             facility  fyear        type  ownership       state region subregion  rural  acute_beds  icu_beds  heart_icu  burn_icu  surgery_icu  other_icu  acute_specialty_total  hospital_total  specialty_icu
# 271        50014       657605               SUTTER AMADOR HOSPITAL   2017  Acute-care        nfp  California   West   Pacific      2          46         6          0         0            0          0                     52              52              0
# 314        50101       657622         SUTTER SOLANO MEDICAL CENTER   2017  Acute-care        nfp  California   West   Pacific      1          96        12          0         0            0          0                    108             108              0
# ...

# %% [markdown]
# ## BLS
#
# Now that businesses are shutting down we want a better idea of how many people work in those industries.

# %%
state_emp = pd.read_excel('../data/bls/oesm18st/state_M2018_dl.xlsx', dtypes={'AREA':str})

# %%
food = state_emp['OCC_CODE'] == '35-0000'
ovr = state_emp['ST'].isin(['KY','OH','WV'])

ovr_food = state_emp.loc[(food)&(ovr)]

# %%
ovr_food

# %%
ovr_food['TOT_EMP'].sum()

# %% [markdown]
# -------------------------
# Ok this isn't working so I'm going to just download the fucking data and move on. I need to get my shit together with a census python tool though. Jesus.

# %%
trows = ['DP05_0001E','DP05_0005E','DP05_0006E','DP05_0007E','DP05_0008E',
         'DP05_0009E','DP05_0010E','DP05_0011E','DP05_0012E','DP05_0013E',
         'DP05_0014E','DP05_0015E','DP05_0016E','DP05_0017E','DP05_0018E',
         'DP05_0023E','DP05_0024E']

ky_cnty = censusdata.download('acs5', 2018,
                             censusdata.censusgeo([('state', '21'), ('county', '*')]),
                             trows)
oh_cnty = censusdata.download('acs5', 2018,
                             censusdata.censusgeo([('state', '39'), ('county', '*')]),
                             trows)
wv_cnty = censusdata.download('acs5', 2018,
                             censusdata.censusgeo([('state', '54'), ('county', '*')]),
                             trows)
